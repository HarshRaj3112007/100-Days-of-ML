# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshRaj3112007/100-Days-of-ML/blob/main/working_with_json_and_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_json('/content/train.json', lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_441/23661538.py in <cell line: 0>()
# ----> 1 df = pd.read_json('/content/train.json', lines=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#     816
#     817
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read(self)
#    1021                         data = ensure_str(self.data)
#    1022                         data_lines = data.split("\n")
# -> 1023                         obj = self._get_object_parser(self._combine_lines(data_lines))
# ...

# %%
pd.read_json("https://www.timestored.com/data/sample/types.json")
# Out:
#      english chinese japanese                              effective  \
# 0     Normal      一般     ノーマル                                     []
# 1   Fighting      格斗     かくとう       [Normal, Ice, Rock, Dark, Steel]
# 2     Flying      飞行      ひこう                 [Grass, Fighting, Bug]
# 3     Poison       毒       どく                         [Grass, Fairy]
# 4     Ground      地上      じめん  [Fire, Electric, Poison, Rock, Steel]
# 5       Rock      岩石       いわ               [Fire, Ice, Flying, Bug]
# 6        Bug       虫       むし                 [Grass, Psychic, Dark]
# 7      Ghost      幽灵     ゴースト                       [Psychic, Ghost]
# 8      Steel       钢      はがね                     [Ice, Rock, Fairy]
# 9       Fire       炎      ほのお               [Grass, Ice, Bug, Steel]
# 10     Water       水       みず                   [Fire, Ground, Rock]
# 11     Grass       草       くさ                  [Water, Ground, Rock]
# 12  Electric       电      でんき                        [Water, Flying]
# ...

# %% [markdown]
# Working with SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 90.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-linux_x86_64.whl size=247950 sha256=57d689d39e3a34a6be40fd2aa7e848debc3c1b932d0ea2f2afa3026610fd6a2e
#   Stored in directory: /root/.cache/pip/wheels/03/17/fa/d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hashtagkehl/worldsql")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 787/787 [00:00<00:00, 428kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/hashtagkehl/worldsql/versions/1

# %%
df = pd.read_csv('/content/worldsql/worldsql.csv')

# %%
import mysql.connector
conn = mysql.connector.connect(host='localhost', user='root', password='',database='world')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/mysql/connector/network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# /tmp/ipykernel_441/1810274761.py in <cell line: 0>()
#       1 import mysql.connector
# ----> 2 conn = mysql.connector.connect(host='localhost', user='root', password='',database='world')
#
# /usr/local/lib/python3.12/dist-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# ...

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_441/4272969784.py in <cell line: 0>()
# ----> 1 df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
#
# NameError: name 'conn' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_441/1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined
